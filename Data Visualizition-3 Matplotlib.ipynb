# %%
import matplotlib.pyplot as plt
import numpy as np
x=([45,78])
y=([89,99])
print(plt.plot(x,y,marker='d'))
print(plt.show())
# Out:
# ...
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([23,45,67,89])
y=([34,22,55,77])
plt.plot(x,y,marker='D')
plt.show()
